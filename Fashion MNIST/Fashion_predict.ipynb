# %%
# !wget https://drive.google.com/file/d/1CrCe3YSRAbVlVbbA7pVBe8teiEbgsG84/view?usp=sharing -O /content/bag.jpg
# Out:
# --2022-08-05 15:02:24--  https://drive.google.com/file/d/1CrCe3YSRAbVlVbbA7pVBe8teiEbgsG84/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 142.251.33.206, 2607:f8b0:4004:832::200e
# Connecting to drive.google.com (drive.google.com)|142.251.33.206|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/bag.jpg’
#
# /content/bag.jpg        [ <=>                ]  67.03K  --.-KB/s    in 0.02s
#
# 2022-08-05 15:02:24 (3.83 MB/s) - ‘/content/bag.jpg’ saved [68641]

# %%
from tensorflow.keras.models import load_model
from google.colab import files
from IPython.display import Image
from tensorflow.keras.preprocessing import image
import numpy as np

classes = ['футболка', 'брюки', 'свитер', 'платье', 'пальто', 'туфли', 'рубашка', 'кроссовки', 'сумка', 'ботинки']

# %%
model = load_model("/content/drive/MyDrive/Colab Notebooks/fashion_mnist.h5")
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_27 (Dense)            (None, 800)               628000
#
#  dense_28 (Dense)            (None, 900)               720900
#
#  dense_29 (Dense)            (None, 10)                9010
#
# ...
# Total params: 1,357,910
# Trainable params: 1,357,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = load_model("/content/drive/MyDrive/Colab Notebooks/Fashion MNIST/fashion_mnist.h5")
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_27 (Dense)            (None, 800)               628000
#
#  dense_28 (Dense)            (None, 900)               720900
#
#  dense_29 (Dense)            (None, 10)                9010
#
# ...
# Total params: 1,357,910
# Trainable params: 1,357,910
# Non-trainable params: 0
# _________________________________________________________________
